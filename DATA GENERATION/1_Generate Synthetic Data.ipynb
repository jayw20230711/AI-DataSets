# %%
import numpy as np
import pandas as pd

cities = ['Berlin', 'Frankfurt', 'Hamburg', 'Nuremberg', 'Munich', 'Stuttgart', 'Hanover', 'Saarbruecken', 'Cologne',
          'Constance', 'Freiburg', 'Karlsruhe']

# %%
n = len(cities)

# %%
data = {'Temperature': np.random.normal(24, 3, n),
        'Humidity': np.random.normal(78, 2.5, n),
        'Wind': np.random.normal(15, 4, n)
       }

df = pd.DataFrame(data=data, index=cities)
df
# Out:
#               Temperature   Humidity       Wind
# Berlin          25.657808  80.950054  10.221607
# Frankfurt       23.755048  79.219224  16.120647
# Hamburg         21.270896  77.162299  20.485531
# Nuremberg       24.096662  75.239932  18.329365
# Munich          23.926852  77.899287   9.713149
# Stuttgart       21.015167  80.737653  13.046950
# Hanover         18.860890  76.796858  17.624064
# Saarbruecken    25.442553  78.967256  16.843349
# Cologne         26.623863  78.723057  25.249103
# Constance       20.564542  79.345504  13.828820
# Freiburg        26.872243  75.756752  18.826458
# Karlsruhe       25.016479  79.085005  20.545513
