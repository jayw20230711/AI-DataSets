# %%
"""
reshape and concatenate
"""

# %%
import numpy as np

a = np.array([[1, 2], [3, 4]])

# %%
a
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
a.shape
# Out:
# (2, 2)

# %%
b = np.array([5, 6])
b
# Out:
# array([5, 6])

# %%
b.shape
# Out:
# (2,)

# %%
b = b.reshape(b.shape[0], 1)
b
# Out:
# array([[5],
#        [6]])

# %%
b.shape
# Out:
# (2, 1)

# %%
x = np.concatenate((a, b), axis=1)
x
# Out:
# array([[1, 2, 5],
#        [3, 4, 6]])

# %%
x.shape
# Out:
# (2, 3)
