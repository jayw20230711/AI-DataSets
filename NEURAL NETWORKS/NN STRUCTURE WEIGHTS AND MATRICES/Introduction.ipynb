# %%
import numpy as np

# %%
"""
The input layer consists of the nodes i1, i2 and i3. In principle the input is a one-dimensional 
vector, like (2, 4,11). A one-dimensional vector is represented in numpy like this:
"""

# %%
input_vector = np.array([2, 4, 11])

print(input_vector)                     
print(type(input_vector))               
print(input_vector.shape)
# Out:
# [ 2  4 11]
# <class 'numpy.ndarray'>
# (3,)

# %%
"""
In the algorithm, which we will write later, we will have to transpose it into a column 
vector, i.e. a twodimensional array with just one column:
"""

# %%
input_vector = np.array([2, 4, 11])
input_vector = np.array(input_vector, ndmin=2).T

print("The input vector: \n", input_vector)
# Out:
# The input vector:
#  [[ 2]
#  [ 4]
#  [11]]

# %%
print("The shape of this vector: ", input_vector.shape)
# Out:
# The shape of this vector:  (3, 1)
